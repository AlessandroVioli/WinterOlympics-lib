# %%
import sys
sys.path.append('.winter_olympics.py')

# %%
import winter_olympics

# %%
# LIST OF THE AVAILABLE OPERATIONS FROM THE LIBRARY
winter_olympics.operations()
# Out:
# Available Functions and Their Descriptions:
#
# - load_shapefile(file_path): Load a shapefile into a GeoDataFrame.
#
# - create_map(gdf): Create a folium map with markers showing locations and their attributes.
#
# - calculate_distances(lat, lon, gdf): Calculate distances from a given latitude and longitude to points in a GeoDataFrame.
#
# - get_user_input_and_calculate_distances(gdf): Prompt user for coordinates and calculate distances to GeoDataFrame points.
#
# - save_geodataframe(gdf, file_path, file_format): Save a GeoDataFrame to a file in specified format (shp, geojson, csv).
#
# - filter_by_attribute(gdf, column_name, value): Filter the GeoDataFrame by a specific column value.
#
# - generate_heatmap(gdf): Generate a heatmap of point density using folium.
#
# - save_map_as_html(m, file_path): Save a folium map as an HTML file.
#
# - save_attributes_to_csv(gdf, file_path): Save the attribute table of a GeoDataFrame to a CSV file.

# %%
#LOADING THE SHAPEFILE
dataframe = winter_olympics.load_shapefile('./olympic locations files/olympic locations.shp')
dataframe
# Out:
#    id               city                           venue_name  \
# 0   1             Milano                     San Siro Stadium
# 1   2             Milano                         Fiera Milano
# 2   3             Bormio                   Stelvio Ski centre
# 3   4            Livigno                    Livigno Snow Park
# 4   5  Cortina d'Ampezzo                       Sliding Centre
# 5   6  Cortina d'Ampezzo                  Olympic Ice Stadium
# 6   7         Anterselva            Anterselva Biathlon arena
# 7   8           Predazzo         Predazzo Ski Jumping Stadium
# 8   9             Tesero  Tesero Cross-Country Skiing Stadium
# 9  10             Verona                      Arena di Verona
#
#                 region                                             events  \
# 0            Lombardia                                   Opening ceremony
# 1            Lombardia                         Figure Skating, Ice Hockey
# 2            Lombardia                  Alpine Skiing, Ski Mountaineering
# 3            Lombardia                     Snowboarding, Freestyle Skiing
# 4               Veneto                          Bobsleigh, Luge, Skeleton
# 5               Veneto                                            Curling
# 6  Trentino Alto-Adige                                           Biathlon
# 7  Trentino Alto-Adige                       Ski Jumping, Nordic Combined
# 8  Trentino Alto-Adige  Cross-Country Skiing, Para Biathlon, Para Cros...
# 9               Veneto                                   Closing Ceremony
#
#                   geometry
# 0   POINT (9.1245 45.4781)
# 1   POINT (9.1432 45.4817)
# 2  POINT (10.3729 46.4691)
# 3  POINT (10.1355 46.5405)
# 4  POINT (12.1378 46.5401)
# 5  POINT (12.1356 46.5399)
# 6  POINT (12.0344 46.8988)
# 7  POINT (11.6165 46.3076)
# 8  POINT (11.5202 46.2831)
# 9  POINT (10.9921 45.4384)

# %%
#CREATING A MAP WITH THE SHAPEFILE LOCATIONS
winter_olympics.create_map(dataframe)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f66715ad16b4b8a202e792d87c5b42a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f66715ad16b4b8a202e792d87c5b42a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f66715ad16b4b8a202e792d87c5b42a3 = L.map(
#                 &quot;map_f66715ad16b4b8a202e792d87c5b42a3&quot;,
#                 {
#                     center: [46.19773, 10.921270000000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a091fda98f989824dc85925db88be46d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a091fda98f989824dc85925db88be46d.addTo(map_f66715ad16b4b8a202e792d87c5b42a3);
#
#
#             var marker_da45bdfc887269fd7356fe7166555bf3 = L.marker(
#                 [45.4781, 9.1245],
#                 {}
#             ).addTo(map_f66715ad16b4b8a202e792d87c5b42a3);
#
#
#         var popup_08ac3681553183ffb9746e1eebd88ab7 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_997781de4f9594152cf98b8bbddbc24f = $(`&lt;div id=&quot;html_997781de4f9594152cf98b8bbddbc24f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;strong&gt;Point ID:&lt;/strong&gt; 0&lt;br&gt;         &lt;strong&gt;Latitude:&lt;/strong&gt; 45.4781&lt;br&gt;         &lt;strong&gt;Longitude:&lt;/strong&gt; 9.1245&lt;br&gt;         &lt;strong&gt;City:&lt;/strong&gt; Milano&lt;br&gt;         &lt;strong&gt;Venue Name:&lt;/strong&gt; San Siro Stadium&lt;br&gt;          &lt;strong&gt;Region:&lt;/strong&gt; Lombardia&lt;br&gt;          &lt;strong&gt;Events:&lt;/strong&gt; Opening ceremony&lt;br&gt;          &lt;/div&gt;`)[0];
#                 popup_08ac3681553183ffb9746e1eebd88ab7.setContent(html_997781de4f9594152cf98b8bbddbc24f);
#
#
#
#         marker_da45bdfc887269fd7356fe7166555bf3.bindPopup(popup_08ac3681553183ffb9746e1eebd88ab7)
#         ;
#
#
#
#
#             var marker_822972aeb9402706d55852ac12386068 = L.marker(
#                 [45.4817, 9.1432],
#                 {}
#             ).addTo(map_f66715ad16b4b8a202e792d87c5b42a3);
#
#
#         var popup_6d7999c3317427a564ca5370afe38449 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_931632e7ddca51a518cfc259ea3607f6 = $(`&lt;div id=&quot;html_931632e7ddca51a518cfc259ea3607f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;strong&gt;Point ID:&lt;/strong&gt; 1&lt;br&gt;         &lt;strong&gt;Latitude:&lt;/strong&gt; 45.4817&lt;br&gt;         &lt;strong&gt;Longitude:&lt;/strong&gt; 9.1432&lt;br&gt;         &lt;strong&gt;City:&lt;/strong&gt; Milano&lt;br&gt;         &lt;strong&gt;Venue Name:&lt;/strong&gt; Fiera Milano&lt;br&gt;          &lt;strong&gt;Region:&lt;/strong&gt; Lombardia&lt;br&gt;          &lt;strong&gt;Events:&lt;/strong&gt; Figure Skating, Ice Hockey&lt;br&gt;          &lt;/div&gt;`)[0];
#                 popup_6d7999c3317427a564ca5370afe38449.setContent(html_931632e7ddca51a518cfc259ea3607f6);
#
#
#
#         marker_822972aeb9402706d55852ac12386068.bindPopup(popup_6d7999c3317427a564ca5370afe38449)
#         ;
#
#
#
#
#             var marker_6dba03ad5bf96070f8a23cc4c5923439 = L.marker(
#                 [46.4691, 10.3729],
#                 {}
#             ).addTo(map_f66715ad16b4b8a202e792d87c5b42a3);
#
#
#         var popup_dafc90d6f4df103166c33967217f8d3e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_fa969585bffb6bcdfc2fa585c9d569c1 = $(`&lt;div id=&quot;html_fa969585bffb6bcdfc2fa585c9d569c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;strong&gt;Point ID:&lt;/strong&gt; 2&lt;br&gt;         &lt;strong&gt;Latitude:&lt;/strong&gt; 46.4691&lt;br&gt;         &lt;strong&gt;Longitude:&lt;/strong&gt; 10.3729&lt;br&gt;         &lt;strong&gt;City:&lt;/strong&gt; Bormio&lt;br&gt;         &lt;strong&gt;Venue Name:&lt;/strong&gt; Stelvio Ski centre&lt;br&gt;          &lt;strong&gt;Region:&lt;/strong&gt; Lombardia&lt;br&gt;          &lt;strong&gt;Events:&lt;/strong&gt; Alpine Skiing, Ski Mountaineering&lt;br&gt;          &lt;/div&gt;`)[0];
#                 popup_dafc90d6f4df103166c33967217f8d3e.setContent(html_fa969585bffb6bcdfc2fa585c9d569c1);
#
#
#
#         marker_6dba03ad5bf96070f8a23cc4c5923439.bindPopup(popup_dafc90d6f4df103166c33967217f8d3e)
#         ;
#
#
#
#
#             var marker_becd56ea7cb346f34c7aef552eff493a = L.marker(
#                 [46.5405, 10.1355],
#                 {}
#             ).addTo(map_f66715ad16b4b8a202e792d87c5b42a3);
#
#
#         var popup_6e438b022d7f05e19f7703a57619f277 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_b5b45d16d8723cbef0c69e1335f777b4 = $(`&lt;div id=&quot;html_b5b45d16d87

# %%
#CALCULATING THE DISTANCES FROM SPECIFIC COORDINATES
lat= 45.46427
long= 9.18951
distance_table= winter_olympics.calculate_distances(lat,long,dataframe)
distance_table
# Out:
#    latitude  longitude  distance_km               city  \
# 0   45.4817     9.1432     4.098268             Milano
# 1   45.4781     9.1245     5.297437             Milano
# 2   46.5405    10.1355   140.211819            Livigno
# 3   45.4384    10.9921   140.637305             Verona
# 4   46.4691    10.3729   144.389976             Bormio
# 5   46.2831    11.5202   202.097993             Tesero
# 6   46.3076    11.6165   209.944912           Predazzo
# 7   46.5399    12.1356   257.048833  Cortina d'Ampezzo
# 8   46.5401    12.1378   257.209195  Cortina d'Ampezzo
# 9   46.8988    12.0344   270.924464         Anterselva
#
#                             venue_name
# 0                         Fiera Milano
# 1                     San Siro Stadium
# 2                    Livigno Snow Park
# 3                      Arena di Verona
# 4                   Stelvio Ski centre
# 5  Tesero Cross-Country Skiing Stadium
# 6         Predazzo Ski Jumping Stadium
# 7                  Olympic Ice Stadium
# 8                       Sliding Centre
# 9            Anterselva Biathlon arena

# %%
#CALCULATING THE DISTANCES FROM USER INPUT'S COORDINATES
winter_olympics.get_user_input_and_calculate_distances(dataframe)
# Out:
# Enter latitude:  45
# Enter longitude:  9
#    latitude  longitude  distance_km               city  \
# 0   45.4781     9.1245    54.048614             Milano
# 1   45.4817     9.1432    54.723447             Milano
# 2   45.4384    10.9921   163.464284             Verona
# 3   46.5405    10.1355   192.605569            Livigno
# 4   46.4691    10.3729   195.028691             Bormio
# 5   46.2831    11.5202   242.347426             Tesero
# 6   46.3076    11.6165   249.974555           Predazzo
# 7   46.5399    12.1356   297.399454  Cortina d'Ampezzo
# 8   46.5401    12.1378   297.551380  Cortina d'Ampezzo
# 9   46.8988    12.0344   315.575023         Anterselva
#
#                             venue_name
# 0                     San Siro Stadium
# 1                         Fiera Milano
# 2                      Arena di Verona
# 3                    Livigno Snow Park
# 4                   Stelvio Ski centre
# 5  Tesero Cross-Country Skiing Stadium
# 6         Predazzo Ski Jumping Stadium
# 7                  Olympic Ice Stadium
# 8                       Sliding Centre
# 9            Anterselva Biathlon arena

# %%
# TEST SAVE GEODATAFRAME FUNCTION
save_path = 'saved_geodataframe.geojson'
winter_olympics.save_geodataframe(dataframe, save_path)
print(f"GeoDataFrame saved to {save_path}")
# Out:
# GeoDataFrame saved to saved_geodataframe.geojson

# %%
# TEST FILTER BY ATTRIBUTE FUNCTION
filtered_gdf = winter_olympics.filter_by_attribute(dataframe, 'region', 'Piemonte')
print("Filtered GeoDataFrame:")
print(filtered_gdf.head())
# Out:
# Filtered GeoDataFrame:
# Empty GeoDataFrame
# Columns: [id, city, venue_name, region, events, geometry, latitude, longitude]
# Index: []

# %%
# GENERATING HEATMAP
heatmap = winter_olympics.generate_heatmap(dataframe)
heatmap.save("heatmap.html")
print("Heatmap saved as heatmap.html")
heatmap
# Out:
# Heatmap saved as heatmap.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71429ec2884e9c78966240d78d89bc56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71429ec2884e9c78966240d78d89bc56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71429ec2884e9c78966240d78d89bc56 = L.map(
#                 &quot;map_71429ec2884e9c78966240d78d89bc56&quot;,
#                 {
#                     center: [46.19773, 10.921270000000002],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7786c5fda8cd1cfda5768e9d268a2015 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7786c5fda8cd1cfda5768e9d268a2015.addTo(map_71429ec2884e9c78966240d78d89bc56);
#
#
#             var heat_map_d501283c70a3405f7574bf4e26117b3a = L.heatLayer(
#                 [[45.4781, 9.1245], [45.4817, 9.1432], [46.4691, 10.3729], [46.5405, 10.1355], [46.5401, 12.1378], [46.5399, 12.1356], [46.8988, 12.0344], [46.3076, 11.6165], [46.2831, 11.5202], [45.4384, 10.9921]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_d501283c70a3405f7574bf4e26117b3a.addTo(map_71429ec2884e9c78966240d78d89bc56);
#
#
#             tile_layer_7786c5fda8cd1cfda5768e9d268a2015.addTo(map_71429ec2884e9c78966240d78d89bc56);
#
#
#             heat_map_d501283c70a3405f7574bf4e26117b3a.addTo(map_71429ec2884e9c78966240d78d89bc56);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# SAVING THE MAP AS HTML
map_object = winter_olympics.create_map(dataframe)
winter_olympics.save_map_as_html(map_object, 'map.html')
print("Map saved as map.html")
# Out:
# Map saved as map.html

# %%
# SAVING THE SHAPEFILE AS CSV
csv_path = 'shapefile_attributes.csv'
winter_olympics.save_attributes_to_csv(dataframe, csv_path)
print(f"Attributes saved as CSV to {csv_path}")
# Out:
# Attributes saved as CSV to shapefile_attributes.csv
